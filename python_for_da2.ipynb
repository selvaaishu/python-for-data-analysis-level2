# %% [markdown]
# <a href="https://colab.research.google.com/github/selvaaishu/python-for-data-analysis-level2/blob/main/python_for_da2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/movies dataset.csv')

# %%
data.head(4)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
#
#                                                STARS    VOTES  RunTime Gross
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...   21,062    121.0   NaN
# ...

# %%
data.isnull()
# Out:
#       MOVIES   YEAR  GENRE  RATING  ONE-LINE  STARS  VOTES  RunTime  Gross
# 0      False  False  False   False     False  False  False    False   True
# 1      False  False  False   False     False  False  False    False   True
# 2      False  False  False   False     False  False  False    False   True
# 3      False  False  False   False     False  False  False    False   True
# 4      False  False  False    True     False  False   True     True   True
# ...      ...    ...    ...     ...       ...    ...    ...      ...    ...
# 9994   False  False  False    True     False  False   True     True   True
# 9995   False  False  False    True     False  False   True     True   True
# 9996   False  False  False    True     False  False   True     True   True
# 9997   False  False  False    True     False  False   True     True   True
# 9998   False  False  False    True     False  False   True     True   True
#
# [9999 rows x 9 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of                                    MOVIES         YEAR  \
# 0                           Blood Red Sky       (2021)
# 1     Masters of the Universe: Revelation     (2021– )
# 2                        The Walking Dead  (2010–2022)
# 3                          Rick and Morty     (2013– )
# 4                         Army of Thieves       (2021)
# ...                                   ...          ...
# 9994                       The Imperfects     (2021– )
# 9995                               Arcane     (2021– )
# 9996                    Heart of Invictus     (2022– )
# 9997                       The Imperfects     (2021– )
# 9998                       The Imperfects     (2021– )
#
#                                            GENRE  RATING  \
# 0         \nAction, Horror, Thriller                 6.1
# 1     \nAnimation, Action, Adventure                 5.0
# 2          \nDrama, Horror, Thriller                 8.2
# ...

# %%
data.describe()
# Out:
#             RATING      RunTime
# count  8179.000000  7041.000000
# mean      6.921176    68.688539
# std       1.220232    47.258056
# min       1.100000     1.000000
# 25%       6.200000    36.000000
# 50%       7.100000    60.000000
# 75%       7.800000    95.000000
# max       9.900000   853.000000

# %%
x=data['MOVIES']
y=data['RATING']
plt.bar(x,y)
plt.xlabel("MOVIES")
plt.ylabel("RATING")
plt.xticks([])
plt.title("MOVIES VS RATING")
plt.show()

# %%
data=pd.read_excel('/content/small dataset.xlsx')

# %%
a=data.head(5)
b=data.tail(5)
print(a)
print(b)
# Out:
#                      Country       Year Rank  Total  C1: Security Apparatus  \
# 0                      Sudan 2006-01-01  1st  112.3                     9.8
# 1  Congo Democratic Republic 2006-01-01  2nd  110.1                     9.8
# 2              Cote d'Ivoire 2006-01-01  3rd  109.2                     9.8
# 3                       Iraq 2006-01-01  4th  109.0                     9.8
# 4                   Zimbabwe 2006-01-01  5th  108.9                     9.4
#
#    C2: Factionalized Elites  C3: Group Grievance  E1: Economy  \
# 0                       9.1                  9.7          7.5
# 1                       9.6                  9.1          8.1
# 2                       9.8                  9.8          9.0
# 3                       9.7                  9.8          8.2
# 4                       8.5                  8.5          9.8
#
#    E2: Economic Inequality  E3: Human Flight and Brain Drain  \
# 0                      9.2                               9.1
# ...

# %%
x=data['Country']
y=data['Rank']
plt.xticks([])
plt.yticks([])
plt.scatter(x,y)

# %%
x=data['Country']
y=data['P3: Human Rights']
plt.plot(x,y)
plt.xticks([])
plt.show()
